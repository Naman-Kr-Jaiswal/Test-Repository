# %% [markdown]
# <a href="https://colab.research.google.com/github/ASHIRWAD-PASWAN/Test-Repository1/blob/main/Task1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# importing all the necessary libraries

# %%
import pandas as pd
import numpy as np
import matplotlib
from matplotlib import pyplot as plt
from sklearn import linear_model
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# %% [markdown]
# Reading the data from the csv file using pandas data frame.

# %%
ipl = pd.read_csv("IPL 2022 Batters.csv")

# %% [markdown]
# checking null values

# %%
ipl.isnull().sum()
# Out:
# Player    0
# Mat       0
# Inns      0
# NO        0
# Runs      0
# HS        0
# Avg       0
# BF        0
# SR        0
# 100       0
# 50        0
# 4s        0
# dtype: int64

# %% [markdown]
# Plotting graphs using Matplotlib

# %%
plt.bar(ipl['4s'],ipl['Inns'])
plt.title("inns vs 4s")
plt.xlabel("4s")
plt.ylabel("inns")
# Out:
# Text(0, 0.5, 'inns')

# %%
plt.scatter(ipl['4s'],ipl['Runs'],color = 'Red',s=10)
plt.title("Runs vs 4s")
plt.xlabel("4s")
plt.ylabel("Runs")
# Out:
# Text(0, 0.5, 'Runs')

# %%
plt.scatter(ipl['4s'],ipl['Avg'],color = 'g',s=10)
plt.title("Avg vs 4s")
plt.xlabel("4s")
plt.ylabel("Avg")
# Out:
# Text(0, 0.5, 'Avg')

# %%
plt.scatter(ipl['4s'],ipl['SR'],color = 'Red',s=10)
plt.title("SR vs 4s")
plt.xlabel("4s")
plt.ylabel("SR")
# Out:
# Text(0, 0.5, 'SR')

# %%
plt.scatter(ipl['4s'],ipl['100'],color = 'Red')
plt.title("100s vs 4s")
plt.xlabel("4s")
plt.ylabel("100s")
# Out:
# Text(0, 0.5, '100s')

# %%
plt.bar(ipl['4s'],ipl['50'],color = 'Red')
plt.title("50s vs 4s")
plt.xlabel("4s")
plt.ylabel("50s")
# Out:
# Text(0, 0.5, '50s')

# %% [markdown]
# performing linear regression on 4s

# %%
reg = linear_model.LinearRegression()

# %% [markdown]
# creating data frames

# %%
fours = ipl['4s']
Str = ipl[['SR','Inns','Runs','100','50']]

# %% [markdown]
# splitting dataset into using train_test_split

# %%
Str_train, Str_test, fours_train, fours_test = train_test_split(
  Str,fours , random_state=104,test_size=0.35, shuffle=True)

# %% [markdown]
# coverting into array

# %%
#SR_train = np.asarray(Str_train)
#SR_test = np.asarray(Str_test)

# %% [markdown]
# reshaping the array

# %%
#SR_train = SR_train.reshape(-1,1)
#SR_test = SR_test.reshape(-1,1)

# %% [markdown]
# training the linear regression model using sklearn on train data and predict the
# values for test data.

# %%
reg.fit(Str_train,fours_train)
fours_pred = reg.predict(Str_test)

# %% [markdown]
# Finding mean square error on train data predictions and test data predictions

# %%
print(mean_squared_error(fours_test,fours_pred))
# Out:
# 284.53966413953816
